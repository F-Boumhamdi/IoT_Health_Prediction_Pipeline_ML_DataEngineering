# %%
# %sql
-- Étape 1 — supprimer les tables
DROP TABLE IF EXISTS iotmlhealthcatalog.gold.vitaldb;
DROP TABLE IF EXISTS iotmlhealthcatalog.silver.vitaldb;
DROP TABLE IF EXISTS iotmlhealthcatalog.bronze.vitaldb;

# %%
# Étape 2 — nettoyer les volumes
dbutils.fs.rm("/Volumes/iotmlhealthcatalog/default/iotbatch/vitaldb_data", True)
dbutils.fs.rm("/Volumes/iotmlhealthcatalog/default/iotbatch/tmp", True)

# %%
# Étape 3 — recréer dossiers propres
dbutils.fs.mkdirs("/Volumes/iotmlhealthcatalog/default/iotbatch/vitaldb_data")
dbutils.fs.mkdirs("/Volumes/iot_traiiotmlhealthcatalogn/default/iotbatch/tmp")
